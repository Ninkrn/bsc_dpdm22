# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninkrn/bsc_dpdm22/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nomalization-Standardization
# https://scikit-learn.org/stable/modules/preprocessing.html

# %%
import pandas as pd

# %%
/#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/BPDM')

# %% [markdown]
# # ใช้ data กรมอุตุ

# %%
weather_data = pd.read_csv('/content/gdrive/MyDrive/BPDM/Group6_2กาญจนสุดา_16วรรณนภา_21เกลิดา_31ศิริขวัญ.csv')

# %%
weather_data.head()
# Out:
#    จังหวัด  วันที่  เดือนที่  ปีที่   ความกด  ความชื้นสัมพัทธ์ ความเร็วลม  \
# 0  ขอนแก่น       1        10   2011  1005.47                83          3
# 1  ขอนแก่น       2        10   2011  1006.65                92          2
# 2  ขอนแก่น       3        10   2011  1007.49                86          3
# 3  ขอนแก่น       4        10   2011  1008.28                80          2
# 4  ขอนแก่น       5        10   2011  1009.88                86          2
#
#   จำนวนเมฆ ปริมาณฝน  อุณหภูมิจุดน้ำค้าง  อุณหภูมิตุ้ม อุณหภูมิต่ำสุด
# 0        9      1.4                24.2          27.6           24.8
# 1       10     17.7                24.0          25.6           23.0
# 2       10        3                22.9          25.6           22.1
# 3        8        0                21.9          25.8           22.8
# 4       10      2.2                21.7          24.3           23.1

# %%
weather_data.shape
# Out:
# (8169, 12)

# %%
data_features = weather_data.iloc[:,4:]
data_features.head()
# Out:
#     ความกด  ความชื้นสัมพัทธ์ ความเร็วลม จำนวนเมฆ ปริมาณฝน  อุณหภูมิจุดน้ำค้าง  \
# 0  1005.47                83          3        9      1.4                24.2
# 1  1006.65                92          2       10     17.7                24.0
# 2  1007.49                86          3       10        3                22.9
# 3  1008.28                80          2        8        0                21.9
# 4  1009.88                86          2       10      2.2                21.7
#
#    อุณหภูมิตุ้ม อุณหภูมิต่ำสุด
# 0          27.6           24.8
# 1          25.6           23.0
# 2          25.6           22.1
# 3          25.8           22.8
# 4          24.3           23.1

# %%
data_features.dtypes
# Out:
# ความกด                float64
# ความชื้นสัมพัทธ์        int64
# ความเร็วลม             object
# จำนวนเมฆ               object
# ปริมาณฝน               object
# อุณหภูมิจุดน้ำค้าง    float64
# อุณหภูมิตุ้ม          float64
# อุณหภูมิต่ำสุด         object
# dtype: object

# %%
data_features.describe()
# Out:
#             ความกด  ความชื้นสัมพัทธ์  อุณหภูมิจุดน้ำค้าง  อุณหภูมิตุ้ม
# count  8169.000000       8169.000000         8169.000000   8169.000000
# mean   1013.016946         69.798262           18.151916     24.868405
# std       3.224640          8.870501            3.775475      2.846185
# min    1002.040000         38.000000            1.500000     11.800000
# 25%    1010.960000         64.000000           15.800000     23.300000
# 50%    1012.800000         69.000000           18.400000     25.300000
# 75%    1015.010000         75.000000           21.000000     27.000000
# max    1026.100000         99.000000           28.400000     31.000000

# %%
data_features[data_features['ความเร็วลม'].eq('-')]
# Out:
#        ความกด  ความชื้นสัมพัทธ์ ความเร็วลม จำนวนเมฆ ปริมาณฝน  \
# 1079  1012.65                87          -        -     53.3
# 1122  1011.47                61          -        -        -
# 1773  1008.50                73          -        4        0
# 1776  1009.51                89          -        7      1.2
# 1856  1009.45                73          -        4        0
# 1862  1011.50                70          -        6        0
# 1927  1015.58                65          -        2        0
# 1995  1014.22                67          -        1        -
# 2063  1013.33                68          -        -        -
# 2125  1011.17                72          -        8        0
# 2172  1011.46                69          -        1        0
# 2173  1010.24                69          -        1        0
# 2176  1010.04                69          -        1        0
# 2523  1010.58                72          -       10      0.1
# ...
