# %% [markdown]
# <a href="https://colab.research.google.com/github/Ninkrn/bsc_dpdm22/blob/main/Quiz_Group.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
/#เชื่อม google drive 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir('/content/gdrive/MyDrive/BPDM')

# %%
import pandas as pd

# %% [markdown]
# เตรียมข้อมูลของ กรม อุตุ ([link](https://drive.google.com/drive/folders/1k6tJcTTv2bKmFz6A5oOWi-sAeTVIQpG4?usp=sharing)) ให้อยู่ในรูปแบบ ตารางด้านล่าง เพื่อเตรียมข้อมูลสำหรับสร้าง Model ทำนาย อุณภูมิต่ำสุดของวันจากค่าอื่นๆ

# %% [markdown]
# ![Screen Shot 2566-01-11 at 09.36.17.png](data:image/png;base64,...)

# %% [markdown]
# column เดือน-ปี สามารถยุบรวมเป็น 1 column ได้

# %% [markdown]
# #ความกด(เปอร์เซ็นต์)

# %% [markdown]
# ##ความกด(เปอร์เซ็นต์) จ.ขอนแก่น

# %%
press_kk = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความกด(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx', sheet_name='Sheet1')
press_kk
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# ##ความกด(เปอร์เซ็นต์) จ.นครพนม

# %%
press_np = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความกด(เปอร์เซ็นต์)/จ.นครพนม.xlsx')
press_np
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# ##ความกด(เปอร์เซ็นต์) จ.เลย

# %%
press_l = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความกด(เปอร์เซ็นต์)/จ.เลย.xlsx')
press_l
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# ##ความกด(เปอร์เซ็นต์) จ.สกลนคร

# %%
press_sk = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความกด(เปอร์เซ็นต์)/จ.สกลนคร.xlsx')
press_sk
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# ##ความกด(เปอร์เซ็นต์) จ.หนองคาย

# %%
press_sk = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความกด(เปอร์เซ็นต์)/จ.หนองคาย.xlsx')
press_sk
# Out:
#    ความกด(เปอร์เซ็นต์)                Unnamed: 1           Unnamed: 2  \
# 0              รายวัน                        NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  ที่                     สถานี             เดือน/ปี
# 3                  NaN                       NaN                  NaN
# 4                  1    352201-หนองคาย จ.หนองคาย  2011-10-01 00:00:00
# 5                  2    352201-หนองคาย จ.หนองคาย  2011-11-01 00:00:00
# 6                  3    352201-หนองคาย จ.หนองคาย  2011-12-01 00:00:00
# 7                  1    352201-หนองคาย จ.หนองคาย  2012-01-01 00:00:00
# 8                  2    352201-หนองคาย จ.หนองคาย  2012-02-01 00:00:00
# 9                  3    352201-หนองคาย จ.หนองคาย  2012-10-01 00:00:00
# 10                 4    352201-หนองคาย จ.หนองคาย  2012-11-01 00:00:00
# 11                 5    352201-หนองคาย จ.หนองคาย  2012-12-01 00:00:00
# ...

# %% [markdown]
# #ความชื้นสัมพัทธ์(เปอร์เซ็นต์)

# %% [markdown]
# ##ความชื้นสัมพัทธ์(เปอร์เซ็นต์) จ.ขอนแก่น

# %%
mois_kk = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความชื้นสัมพัทธ์(เปอร์เซ็นต์)/จ.ขอนแก่น.xlsx')
mois_kk
# Out:
#    ความชื้นสัมพัทธ์(เปอร์เซ็นต์)                Unnamed: 1  \
# 0                        รายวัน                        NaN
# 1                            NaN                       NaN
# 2                            ที่                     สถานี
# 3                            NaN                       NaN
# 4                            1    381201-ขอนแก่น จ.ขอนแก่น
# 5                            2    381201-ขอนแก่น จ.ขอนแก่น
# 6                            3    381201-ขอนแก่น จ.ขอนแก่น
# 7                            1    381201-ขอนแก่น จ.ขอนแก่น
# 8                            2    381201-ขอนแก่น จ.ขอนแก่น
# 9                            3    381201-ขอนแก่น จ.ขอนแก่น
# 10                           4    381201-ขอนแก่น จ.ขอนแก่น
# 11                           5    381201-ขอนแก่น จ.ขอนแก่น
# 12                           6    381201-ขอนแก่น จ.ขอนแก่น
# 13                           7    381201-ขอนแก่น จ.ขอนแก่น
# 14                           8    381201-ขอนแก่น จ.ขอนแก่น
# ...

# %% [markdown]
# #ความเร็วลม(นอต)

# %% [markdown]
# ##ความเร็วลม(นอต) จ.ขอนแก่น

# %%
wind_kk = pd.read_excel('/content/gdrive/MyDrive/BPDM/ความเร็วลม(นอต)/จ.ขอนแก่น.xlsx')
wind_kk
# Out:
#    ความเร็วลม(นอต)             Unnamed: 1           Unnamed: 2 Unnamed: 3  \
# 0          รายวัน                     NaN                  NaN  จ.ขอนแก่น
# 1              NaN                    NaN                  NaN        NaN
# 2              ที่                  สถานี             เดือน/ปี     วันที่
# 3              NaN                    NaN                  NaN          1
# 4              1    353301-เลย สกษ. จ.เลย  2011-10-01 00:00:00          3
# 5              2    353301-เลย สกษ. จ.เลย  2011-11-01 00:00:00          4
# 6              3    353301-เลย สกษ. จ.เลย  2011-12-01 00:00:00          3
# 7              1    353301-เลย สกษ. จ.เลย  2012-01-01 00:00:00          4
# 8              2    353301-เลย สกษ. จ.เลย  2012-02-01 00:00:00          2
# 9              3    353301-เลย สกษ. จ.เลย  2012-10-01 00:00:00          2
# 10             4    353301-เลย สกษ. จ.เลย  2012-11-01 00:00:00          3
# 11             5    353301-เลย สกษ. จ.เลย  2012-12-01 00:00:00          2
# ...
